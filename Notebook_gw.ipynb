# %% [markdown]
# # This is my first notebook

# %% [markdown]
# ## Import packages

# %% [markdown]
# Here is where we *import packages*. [My repository](https://github.com/guiwitz/reproducible_science). $L_b = e^{t/\tau}$.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
3*3
# Out:
# 9

# %%
a = 3
b = 4
c = a*b

# %%
plt.plot(np.random.rand(100))
plt.show()
